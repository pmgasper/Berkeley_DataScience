# %% [markdown]
# ## Foundations of Data Science: Computational Thinking with Python
#
# Mirroring course Jupyter notebook except using standard modules instead of Berkeley data science module.
#
# ## Lecture 11: Joins

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('fivethirtyeight')
pd.set_option('max_rows', 9)

# %%
drinks = pd.DataFrame([
    ['Milk Tea', 'Tea One', 4],
    ['Espresso', 'Nefeli',  2],
    ['Latte',    'Nefeli',  3],
    ['Espresso', "Abe's",   2]],
    columns=['Drink', 'Cafe', 'Price'])
display(drinks)

discounts = pd.DataFrame({
    'Coupon % off': [25, 50, 5],
    'Location': ['Tea One', 'Nefeli', 'Tea One']})
discounts
# Out:
#       Drink     Cafe  Price
# 0  Milk Tea  Tea One      4
# 1  Espresso   Nefeli      2
# 2     Latte   Nefeli      3
# 3  Espresso    Abe's      2
#    Coupon % off Location
# 0            25  Tea One
# 1            50   Nefeli
# 2             5  Tea One

# %%
tea = drinks.set_index('Cafe').join(discounts.set_index('Location'), how='inner')
tea
# Out:
#             Drink  Price  Coupon % off
# Nefeli   Espresso      2            50
# Nefeli      Latte      3            50
# Tea One  Milk Tea      4            25
# Tea One  Milk Tea      4             5

# %%
tea['Discounted'] = tea.Price * (1 - (tea['Coupon % off'] / 100))
tea
# Out:
#             Drink  Price  Coupon % off  Discounted
# Nefeli   Espresso      2            50         1.0
# Nefeli      Latte      3            50         1.5
# Tea One  Milk Tea      4            25         3.0
# Tea One  Milk Tea      4             5         3.8

# %%
# Self join
#  All combinations of two drinks
two = drinks.set_index('Cafe').join(drinks.set_index('Cafe'), 
                                    lsuffix='_1', rsuffix='_2')
two
# Out:
#           Drink_1  Price_1   Drink_2  Price_2
# Cafe
# Abe's    Espresso        2  Espresso        2
# Nefeli   Espresso        2  Espresso        2
# Nefeli   Espresso        2     Latte        3
# Nefeli      Latte        3  Espresso        2
# Nefeli      Latte        3     Latte        3
# Tea One  Milk Tea        4  Milk Tea        4

# %% [markdown]
# ### Bikes example

# %%
trips = pd.read_csv('data/trip.csv')
trips
# Out:
#         Trip ID  Duration       Start Date  \
# 0        913460       765  8/31/2015 23:26
# 1        913459      1036  8/31/2015 23:11
# 2        913455       307  8/31/2015 23:13
# 3        913454       409  8/31/2015 23:10
# ...         ...       ...              ...
# 354148   432950      6712    9/1/2014 3:16
# 354149   432949       538    9/1/2014 0:05
# 354150   432948       568    9/1/2014 0:05
# 354151   432947       569    9/1/2014 0:05
#
#                                Start Station  Start Terminal         End Date  \
# 0       Harry Bridges Plaza (Ferry Building)              50  8/31/2015 23:39
# 1                San Antonio Shopping Center              31  8/31/2015 23:28
# 2                             Post at Kearny              47  8/31/2015 23:18
# 3                         San Jose City Hall              10  8/31/2015 23:17
# ...                                      ...             ...              ...
# 354148  Harry Bridges Plaza (Ferry Building)              50    9/1/2014 5:08
# 354149              South Van Ness at Market              66    9/1/2014 0:14
# 354150              South Van Ness at Market              66    9/1/2014 0:15
# 354151              South Van Ness at Market              66    9/1/2014 0:15
#
#                                      End Station  End Terminal  Bike #  \
# 0       San Francisco Caltrain (Townsend at 4th)            70     288
# 1                        Mountain View City Hall            27      35
# 2                              2nd at South Park            64     468
# 3                            San Salvador at 1st             8      68
# ...                                          ...           ...     ...
# 354148  San Francisco Caltrain (Townsend at 4th)            70     259
# 354149                             5th at Howard            57     466
# 354150                             5th at Howard            57     461
# 354151                             5th at Howard            57     318
#
#        Subscriber Type Zip Code
# 0           Subscriber     2139
# 1           Subscriber    95032
# 2           Subscriber    94107
# 3           Subscriber    95113
# ...                ...      ...
# 354148        Customer    44100
# 354149        Customer       32
# 354150        Customer       32
# 354151        Customer       32
#
# [354152 rows x 11 columns]

# %%
trips.Duration.describe()
# Out:
# count    3.541520e+05
# mean     1.046033e+03
# std      3.001694e+04
# min      6.000000e+01
# 25%      3.420000e+02
# 50%      5.110000e+02
# 75%      7.390000e+02
# max      1.727040e+07
# Name: Duration, dtype: float64

# %%
trips.columns
# Out:
# Index(['Trip ID', 'Duration', 'Start Date', 'Start Station', 'Start Terminal',
#        'End Date', 'End Station', 'End Terminal', 'Bike #', 'Subscriber Type',
#        'Zip Code'],
#       dtype='object')

# %%
# commute = table of trips under 30min
commute = trips.loc[trips.Duration < 1800]

fig = plt.figure()
ax = commute.Duration.plot.hist(density=True, bins=60, alpha=0.5)
print(type(ax))
fig.set_size_inches(8, 6)
plt.show()
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
starts = commute.loc[:, 'Start Station'].value_counts().to_frame()
starts
# Out:
#                                                Start Station
# San Francisco Caltrain (Townsend at 4th)               25858
# San Francisco Caltrain 2 (330 Townsend)                21523
# Harry Bridges Plaza (Ferry Building)                   15543
# Temporary Transbay Terminal (Howard at Beale)          14298
# ...                                                      ...
# Redwood City Medical Center                              139
# San Mateo County Center                                  108
# Redwood City Public Library                              101
# Franklin at Maple                                         62
#
# [70 rows x 1 columns]

# %%
commute.pivot_table('Trip ID', 'End Station', 'Start Station', aggfunc=len, 
                    fill_value=0, dropna=False)
# Out:
# Start Station                                  2nd at Folsom  \
# End Station
# 2nd at Folsom                                             54
# 2nd at South Park                                        295
# 2nd at Townsend                                          437
# 5th at Howard                                            113
# ...                                                      ...
# Townsend at 7th                                          347
# University and Emerson                                     0
# Washington at Kearny                                     142
# Yerba Buena Center of the Arts (3rd @ Howard)             83
#
# Start Station                                  2nd at South Park  \
# End Station
# 2nd at Folsom                                                190
# 2nd at South Park                                            164
# 2nd at Townsend                                              151
# 5th at Howard                                                177
# ...                                                          ...
# Townsend at 7th                                              309
# University and Emerson                                         0
# Washington at Kearny                                         142
# Yerba Buena Center of the Arts (3rd @ Howard)                180
#
# Start Station                                  2nd at Townsend  5th at Howard  \
# End Station
# 2nd at Folsom                                              554            107
# 2nd at South Park                                           71            180
# 2nd at Townsend                                            185             92
# 5th at Howard                                              148             83
# ...                                                        ...            ...
# Townsend at 7th                                            418            313
# University and Emerson                                       0              0
# Washington at Kearny                                        72             47
# Yerba Buena Center of the Arts (3rd @ Howard)              174             90
#
# Start Station                                  Adobe on Almaden  \
# End Station
# 2nd at Folsom                                                 0
# 2nd at South Park                                             0
# 2nd at Townsend                                               0
# 5th at Howard                                                 0
# ...                                                         ...
# Townsend at 7th                                               0
# University and Emerson                                        0
# Washington at Kearny                                          0
# Yerba Buena Center of the Arts (3rd @ Howard)                 0
#
# Start Station                                  Arena Green / SAP Center  \
# End Station
# 2nd at Folsom                                                         0
# 2nd at South Park                                                     0
# 2nd at Townsend                                                       0
# 5th at Howard                                                         0
# ...                                                                 ...
# Townsend at 7th                                                       0
# University and Emerson                                                0
# Washington at Kearny                                                  0
# Yerba Buena Center of the Arts (3rd @ Howard)                         0
#
# Start Station                                  Beale at Market  \
# End Station
# 2nd at Folsom                                               40
# 2nd at South Park                                          208
# 2nd at Townsend                                            608
# 5th at Howard                                               59
# ...                                                        ...
# Townsend at 7th                                             55
# University and Emerson                                       0
# Washington at Kearny                                        57
# Yerba Buena Center of the Arts (3rd @ Howard)               65
#
# Start Station                                  Broadway St at Battery St  \
# End Station
# 2nd at Folsom                                                         21
# 2nd at South Park                                                     85
# 2nd at Townsend                                                      350
# 5th at Howard                                                        130
# ...                                                                  ...
# Townsend at 7th                                                       43
# University and Emerson                                                 0
# Washington at Kearny                                                  25
# Yerba Buena Center of the Arts (3rd @ Howard)                         34
#
# Start Station                                  California Ave Caltrain Station  \
# End Station
# 2nd at Folsom                                                                0
# 2nd at South Park                                                            0
# 2nd at Townsend                                                              0
# 5th at Howard                                                                0
# ...                                                                        ...
# Townsend at 7th                                                              0
# University and Emerson                                                      82
# Washington at Kearny                                                         0
# Yerba Buena Center of the Arts (3rd @ Howard)                                0
#
# Start Station                                  Castro Street and El Camino Real  \
# End Station
# 2nd at Folsom                                                                 0
# 2nd at South Park                                                             0
# 2nd at Townsend                                                               0
# 5th at Howard                                                                 0
# ...                                                                         ...
# Townsend at 7th                                                               0
# University and Emerson                                                        0
# Washington at Kearny                                                          0
# Yerba Buena Center of the Arts (3rd @ Howard)                                 0
#
# Start Station                                                      ...                        \
# End Station                                                        ...
# 2nd at Folsom                                                      ...
# 2nd at South Park                                                  ...
# 2nd at Townsend                                                    ...
# 5th at Howard                                                      ...
# ...                                                                ...
# Townsend at 7th                                                    ...
# University and Emerson                                             ...
# Washington at Kearny                                               ...
# Yerba Buena Center of the Arts (3rd @ Howard)                      ...
#
# Start Station                                  South Van Ness at Market  \
# End Station
# 2nd at Folsom                                                        38
# 2nd at South Park                                                    66
# 2nd at Townsend                                                      72
# 5th at Howard                                                       116
# ...                                                                 ...
# Townsend at 7th                                                     344
# University and Emerson                                                0
# Washington at Kearny                                                 62
# Yerba Buena Center of the Arts (3rd @ Howard)                        75
#
# Start Station                                  Spear at Folsom  St James Park  \
# End Station
# 2nd at Folsom                                               57              0
# 2nd at South Park                                          152              0
# 2nd at Townsend                                            508              0
# 5th at Howard                                              102              0
# ...                                                        ...            ...
# Townsend at 7th                                            464              0
# University and Emerson                                       0              0
# Washington at Kearny                                        24              0
# Yerba Buena Center of the Arts (3rd @ Howard)              141              0
#
# Start Station                                  Stanford in Redwood City  \
# End Station
# 2nd at Folsom                                                         0
# 2nd at South Park                                                     0
# 2nd at Townsend                                                       0
# 5th at Howard                                                         0
# ...                                                                 ...
# Townsend at 7th                                                       0
# University and Emerson                                                0
# Washington at Kearny                                                  0
# Yerba Buena Center of the Arts (3rd @ Howard)                         0
#
# Start Station                                  Steuart at Market  \
# End Station
# 2nd at Folsom                                                 39
# 2nd at South Park                                            374
# 2nd at Townsend                                             2349
# 5th at Howard                                                182
# ...                                                          ...
# Townsend at 7th                                              734
# University and Emerson                                         0
# Washington at Kearny                                         107
# Yerba Buena Center of the Arts (3rd @ Howard)                214
#
# Start Station                                  Temporary Transbay Terminal (Howard at Beale)  \
# End Station
# 2nd at Folsom                                                                            237
# 2nd at South Park                                                                        429
# 2nd at Townsend                                                                          784
# 5th at Howard                                                                            750
# ...                                                                                      ...
# Townsend at 7th                                                                          825
# University and Emerson                                                                     0
# Washington at Kearny                                                                      90
# Yerba Buena Center of the Arts (3rd @ Howard)                                            403
#
# Start Station                                  Townsend at 7th  \
# End Station
# 2nd at Folsom                                              342
# 2nd at South Park                                          143
# 2nd at Townsend                                            417
# 5th at Howard                                              200
# ...                                                        ...
# Townsend at 7th                                            132
# University and Emerson                                       0
# Washington at Kearny                                        29
# Yerba Buena Center of the Arts (3rd @ Howard)              153
#
# Start Station                                  University and Emerson  \
# End Station
# 2nd at Folsom                                                       0
# 2nd at South Park                                                   0
# 2nd at Townsend                                                     0
# 5th at Howard                                                       0
# ...                                                               ...
# Townsend at 7th                                                     0
# University and Emerson                                             62
# Washington at Kearny                                                0
# Yerba Buena Center of the Arts (3rd @ Howard)                       0
#
# Start Station                                  Washington at Kearny  \
# End Station
# 2nd at Folsom                                                    17
# 2nd at South Park                                                63
# 2nd at Townsend                                                  57
# 5th at Howard                                                    43
# ...                                                             ...
# Townsend at 7th                                                  53
# University and Emerson                                            0
# Washington at Kearny                                             55
# Yerba Buena Center of the Arts (3rd @ Howard)                    36
#
# Start Station                                  Yerba Buena Center of the Arts (3rd @ Howard)
# End Station
# 2nd at Folsom                                                                             31
# 2nd at South Park                                                                        209
# 2nd at Townsend                                                                          166
# 5th at Howard                                                                            267
# ...                                                                                      ...
# Townsend at 7th                                                                          261
# University and Emerson                                                                     0
# Washington at Kearny                                                                      66
# Yerba Buena Center of the Arts (3rd @ Howard)                                             73
#
# [70 rows x 70 columns]

# %%
commute.pivot_table('Duration', 'End Station', 'Start Station', aggfunc=np.min)
# Out:
# Start Station                                  2nd at Folsom  \
# End Station
# 2nd at Folsom                                           61.0
# 2nd at South Park                                       61.0
# 2nd at Townsend                                        137.0
# 5th at Howard                                          215.0
# ...                                                      ...
# Townsend at 7th                                        399.0
# University and Emerson                                   NaN
# Washington at Kearny                                   266.0
# Yerba Buena Center of the Arts (3rd @ Howard)          145.0
#
# Start Station                                  2nd at South Park  \
# End Station
# 2nd at Folsom                                               97.0
# 2nd at South Park                                           60.0
# 2nd at Townsend                                             67.0
# 5th at Howard                                              300.0
# ...                                                          ...
# Townsend at 7th                                            324.0
# University and Emerson                                       NaN
# Washington at Kearny                                       378.0
# Yerba Buena Center of the Arts (3rd @ Howard)              212.0
#
# Start Station                                  2nd at Townsend  5th at Howard  \
# End Station
# 2nd at Folsom                                            164.0          268.0
# 2nd at South Park                                         77.0           86.0
# 2nd at Townsend                                           60.0          423.0
# 5th at Howard                                            384.0           68.0
# ...                                                        ...            ...
# Townsend at 7th                                          319.0          330.0
# University and Emerson                                     NaN            NaN
# Washington at Kearny                                     464.0          269.0
# Yerba Buena Center of the Arts (3rd @ Howard)            299.0          128.0
#
# Start Station                                  Adobe on Almaden  \
# End Station
# 2nd at Folsom                                               NaN
# 2nd at South Park                                           NaN
# 2nd at Townsend                                             NaN
# 5th at Howard                                               NaN
# ...                                                         ...
# Townsend at 7th                                             NaN
# University and Emerson                                      NaN
# Washington at Kearny                                        NaN
# Yerba Buena Center of the Arts (3rd @ Howard)               NaN
#
# Start Station                                  Arena Green / SAP Center  \
# End Station
# 2nd at Folsom                                                       NaN
# 2nd at South Park                                                   NaN
# 2nd at Townsend                                                     NaN
# 5th at Howard                                                       NaN
# ...                                                                 ...
# Townsend at 7th                                                     NaN
# University and Emerson                                              NaN
# Washington at Kearny                                                NaN
# Yerba Buena Center of the Arts (3rd @ Howard)                       NaN
#
# Start Station                                  Beale at Market  \
# End Station
# 2nd at Folsom                                            271.0
# 2nd at South Park                                         78.0
# 2nd at Townsend                                          311.0
# 5th at Howard                                            357.0
# ...                                                        ...
# Townsend at 7th                                          614.0
# University and Emerson                                     NaN
# Washington at Kearny                                     142.0
# Yerba Buena Center of the Arts (3rd @ Howard)            262.0
#
# Start Station                                  Broadway St at Battery St  \
# End Station
# 2nd at Folsom                                                      407.0
# 2nd at South Park                                                  345.0
# 2nd at Townsend                                                    469.0
# 5th at Howard                                                      530.0
# ...                                                                  ...
# Townsend at 7th                                                    822.0
# University and Emerson                                               NaN
# Washington at Kearny                                                69.0
# Yerba Buena Center of the Arts (3rd @ Howard)                      420.0
#
# Start Station                                  California Ave Caltrain Station  \
# End Station
# 2nd at Folsom                                                              NaN
# 2nd at South Park                                                          NaN
# 2nd at Townsend                                                            NaN
# 5th at Howard                                                              NaN
# ...                                                                        ...
# Townsend at 7th                                                            NaN
# University and Emerson                                                   592.0
# Washington at Kearny                                                       NaN
# Yerba Buena Center of the Arts (3rd @ Howard)                              NaN
#
# Start Station                                  Castro Street and El Camino Real  \
# End Station
# 2nd at Folsom                                                               NaN
# 2nd at South Park                                                           NaN
# 2nd at Townsend                                                             NaN
# 5th at Howard                                                               NaN
# ...                                                                         ...
# Townsend at 7th                                                             NaN
# University and Emerson                                                      NaN
# Washington at Kearny                                                        NaN
# Yerba Buena Center of the Arts (3rd @ Howard)                               NaN
#
# Start Station                                                      ...                        \
# End Station                                                        ...
# 2nd at Folsom                                                      ...
# 2nd at South Park                                                  ...
# 2nd at Townsend                                                    ...
# 5th at Howard                                                      ...
# ...                                                                ...
# Townsend at 7th                                                    ...
# University and Emerson                                             ...
# Washington at Kearny                                               ...
# Yerba Buena Center of the Arts (3rd @ Howard)                      ...
#
# Start Station                                  South Van Ness at Market  \
# End Station
# 2nd at Folsom                                                     590.0
# 2nd at South Park                                                 399.0
# 2nd at Townsend                                                   777.0
# 5th at Howard                                                     375.0
# ...                                                                 ...
# Townsend at 7th                                                   351.0
# University and Emerson                                              NaN
# Washington at Kearny                                              514.0
# Yerba Buena Center of the Arts (3rd @ Howard)                     464.0
#
# Start Station                                  Spear at Folsom  St James Park  \
# End Station
# 2nd at Folsom                                            208.0            NaN
# 2nd at South Park                                         63.0            NaN
# 2nd at Townsend                                          241.0            NaN
# 5th at Howard                                            402.0            NaN
# ...                                                        ...            ...
# Townsend at 7th                                          514.0            NaN
# University and Emerson                                     NaN            NaN
# Washington at Kearny                                     341.0            NaN
# Yerba Buena Center of the Arts (3rd @ Howard)            287.0            NaN
#
# Start Station                                  Stanford in Redwood City  \
# End Station
# 2nd at Folsom                                                       NaN
# 2nd at South Park                                                   NaN
# 2nd at Townsend                                                     NaN
# 5th at Howard                                                       NaN
# ...                                                                 ...
# Townsend at 7th                                                     NaN
# University and Emerson                                              NaN
# Washington at Kearny                                                NaN
# Yerba Buena Center of the Arts (3rd @ Howard)                       NaN
#
# Start Station                                  Steuart at Market  \
# End Station
# 2nd at Folsom                                              318.0
# 2nd at South Park                                           79.0
# 2nd at Townsend                                            291.0
# 5th at Howard                                              455.0
# ...                                                          ...
# Townsend at 7th                                            624.0
# University and Emerson                                       NaN
# Washington at Kearny                                       165.0
# Yerba Buena Center of the Arts (3rd @ Howard)              320.0
#
# Start Station                                  Temporary Transbay Terminal (Howard at Beale)  \
# End Station
# 2nd at Folsom                                                                          149.0
# 2nd at South Park                                                                       61.0
# 2nd at Townsend                                                                        249.0
# 5th at Howard                                                                          265.0
# ...                                                                                      ...
# Townsend at 7th                                                                        534.0
# University and Emerson                                                                   NaN
# Washington at Kearny                                                                   248.0
# Yerba Buena Center of the Arts (3rd @ Howard)                                          190.0
#
# Start Station                                  Townsend at 7th  \
# End Station
# 2nd at Folsom                                            448.0
# 2nd at South Park                                         78.0
# 2nd at Townsend                                          259.0
# 5th at Howard                                            357.0
# ...                                                        ...
# Townsend at 7th                                           61.0
# University and Emerson                                     NaN
# Washington at Kearny                                     642.0
# Yerba Buena Center of the Arts (3rd @ Howard)            479.0
#
# Start Station                                  University and Emerson  \
# End Station
# 2nd at Folsom                                                     NaN
# 2nd at South Park                                                 NaN
# 2nd at Townsend                                                   NaN
# 5th at Howard                                                     NaN
# ...                                                               ...
# Townsend at 7th                                                   NaN
# University and Emerson                                           93.0
# Washington at Kearny                                              NaN
# Yerba Buena Center of the Arts (3rd @ Howard)                     NaN
#
# Start Station                                  Washington at Kearny  \
# End Station
# 2nd at Folsom                                                 429.0
# 2nd at South Park                                             270.0
# 2nd at Townsend                                               610.0
# 5th at Howard                                                 553.0
# ...                                                             ...
# Townsend at 7th                                               817.0
# University and Emerson                                          NaN
# Washington at Kearny                                           65.0
# Yerba Buena Center of the Arts (3rd @ Howard)                 360.0
#
# Start Station                                  Yerba Buena Center of the Arts (3rd @ Howard)
# End Station
# 2nd at Folsom                                                                          165.0
# 2nd at South Park                                                                       96.0
# 2nd at Townsend                                                                        284.0
# 5th at Howard                                                                          109.0
# ...                                                                                      ...
# Townsend at 7th                                                                        432.0
# University and Emerson                                                                   NaN
# Washington at Kearny                                                                   190.0
# Yerba Buena Center of the Arts (3rd @ Howard)                                           60.0
#
# [70 rows x 70 columns]

# %%
commute.groupby(['Start Station', 'End Station']).Duration.min().to_frame()
# Out:
#                                                                                              Duration
# Start Station                                 End Station
# 2nd at Folsom                                 2nd at Folsom                                        61
#                                               2nd at South Park                                    61
#                                               2nd at Townsend                                     137
#                                               5th at Howard                                       215
# ...                                                                                               ...
# Yerba Buena Center of the Arts (3rd @ Howard) Temporary Transbay Terminal (Howard at Beale)       226
#                                               Townsend at 7th                                     432
#                                               Washington at Kearny                                190
#                                               Yerba Buena Center of the Arts (3rd @ Howard)        60
#
# [1629 rows x 1 columns]

# %%
(commute
 .loc[commute['Start Station'].str.contains('Civic Center BART')]
 .groupby(['Start Station', 'End Station']).Duration.min()
 .sort_values()
 .to_frame()
)
# Out:
#                                                                      Duration
# Start Station                     End Station
# Civic Center BART (7th at Market) Civic Center BART (7th at Market)        60
#                                   Powell Street BART                       97
#                                   Market at 10th                          104
#                                   Golden Gate at Polk                     141
# ...                                                                       ...
#                                   Spear at Folsom                         611
#                                   Embarcadero at Bryant                   676
#                                   Embarcadero at Sansome                  703
#                                   Embarcadero at Vallejo                  831
#
# [35 rows x 1 columns]

# %% [markdown]
# ### Maps

# %%
stations = pd.read_csv('data/station.csv')
stations
# Out:
#     station_id                               name        lat        long  \
# 0            2  San Jose Diridon Caltrain Station  37.329732 -121.901782
# 1            3              San Jose Civic Center  37.330698 -121.888979
# 2            4             Santa Clara at Almaden  37.333988 -121.894902
# 3            5                   Adobe on Almaden  37.331415 -121.893200
# ..         ...                                ...        ...         ...
# 66          80    Santa Clara County Civic Center  37.352601 -121.905733
# 67          82          Broadway St at Battery St  37.798541 -122.400862
# 68          83                         Mezes Park  37.491269 -122.236234
# 69          84                        Ryland Park  37.342725 -121.895617
#
#     dockcount       landmark installation
# 0          27       San Jose     8/6/2013
# 1          15       San Jose     8/5/2013
# 2          11       San Jose     8/6/2013
# 3          19       San Jose     8/5/2013
# ..        ...            ...          ...
# 66         15       San Jose   12/31/2013
# 67         15  San Francisco    1/22/2014
# 68         15   Redwood City    2/20/2014
# 69         15       San Jose     4/9/2014
#
# [70 rows x 7 columns]
